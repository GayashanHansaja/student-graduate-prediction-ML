# %% [markdown]
# # K-Nearest Neighbors Regressor (KNN) - Flood Prediction\n\n## Member Details\n- Name: \n- Student ID: \n- Email: \n\n## Tasks\n- Load dataset\n- Preprocess features\n- Train and evaluate K-Nearest Neighbors Regressor (KNN)\n- Report MAE, RMSE, and R²\n

# %%
# TODO: Implement dataset loading and preprocessing\nimport pandas as pd\nimport numpy as np\n

# %%
# TODO: Implement model training and evaluation\n
